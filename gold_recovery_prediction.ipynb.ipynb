# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# ## Introducción
#
# Zyfra desarrolla soluciones de eficiencia para la industria pesada. El objetivo de este proyecto es construir un modelo que prediga la recuperación de oro en dos etapas del proceso de producción: recuperación rougher y recuperación final. Esto ayudará a optimizar la producción y eliminar parámetros no rentables.
#
# ### Archivos utilizados:
# - `gold_recovery_train.csv`: conjunto de entrenamiento
# - `gold_recovery_test.csv`: conjunto de prueba
# - `gold_recovery_full.csv`: conjunto completo
#
# Las tareas incluyen: preparación y análisis de datos, construcción del modelo, evaluación con sMAPE y extracción de conclusiones.

# %% [markdown]
# # Paso 1.1 Preparar datos.
# Abrir y examinar datos.
#
# Vamos a importar las bibliotecas necesarias, cargar los tres archivos y observar su estructura.

# %%
# Importación de bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo
sns.set(style="whitegrid")
pd.set_option('display.max_columns', None)

# Cargar los archivos
train = pd.read_csv('/datasets/gold_recovery_train.csv', index_col='date', parse_dates=True)
test = pd.read_csv('/datasets/gold_recovery_test.csv', index_col='date', parse_dates=True)
full = pd.read_csv('/datasets/gold_recovery_full.csv', index_col='date', parse_dates=True)

# Primer vistazo a cada uno
print("Conjunto de entrenamiento:")
display(train.head())
print("\nConjunto de prueba:")
display(test.head())
print("\nConjunto completo:")
display(full.head())

# Tamaño de cada conjunto
print("\nTamaños:")
print("Entrenamiento:", train.shape)
print("Prueba:", test.shape)
print("Completo:", full.shape)
# Out:
# Conjunto de entrenamiento:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# ...

# %% [markdown]
# # Paso 1.2. Verificar el cálculo de recuperación (recovery)
#
# Comprueba que el cálculo de la recuperación sea correcto. Calcula la recuperación de la característica (`rougher.output.recovery`) mediante el conjunto de entrenamiento. Encuentra el EAM entre tus cálculos y los valores de la característica. Facilita los resultados.

# %%
from sklearn.metrics import mean_absolute_error

# Extraer las columnas necesarias
C = train['rougher.output.concentrate_au']
F = train['rougher.input.feed_au']
T = train['rougher.output.tail_au']

# Calcular la recuperación según la fórmula
recovery_calc = (C * (F - T)) / (F * (C - T)) * 100

# Recuperación real
recovery_real = train['rougher.output.recovery']

# Crear un DataFrame para filtrar valores válidos
recovery_df = pd.DataFrame({
    'real': recovery_real,
    'calc': recovery_calc
}).replace([np.inf, -np.inf], np.nan).dropna()

# Calcular MAE
mae = mean_absolute_error(recovery_df['real'], recovery_df['calc'])

print(f'Error Absoluto Medio (MAE) entre recuperación calculada y real: {mae:.4f}')
# Out:
# Error Absoluto Medio (MAE) entre recuperación calculada y real: 0.0000

# %%
from sklearn.metrics import mean_absolute_error

# Extraer las columnas necesarias
C = train['rougher.output.concentrate_au']
F = train['rougher.input.feed_au']
T = train['rougher.output.tail_au']

# Calcular la recuperación según la fórmula
recovery_calc = (C * (F - T)) / (F * (C - T)) * 100

# Recuperación real
recovery_real = train['rougher.output.recovery']

# Crear un DataFrame para filtrar valores válidos
recovery_df = pd.DataFrame({
    'real': recovery_real,
    'calc': recovery_calc
}).replace([np.inf, -np.inf], np.nan).dropna()

# Calcular MAE
mae = mean_absolute_error(recovery_df['real'], recovery_df['calc'])

print(f'Error Absoluto Medio (MAE) entre recuperación calculada y real: {mae:.4f}')
# Out:
# Error Absoluto Medio (MAE) entre recuperación calculada y real: 0.0000

# %% [markdown]
# ### 1.3. Análisis de características no disponibles en el conjunto de prueba
#
# Vamos a comparar las columnas disponibles en el conjunto de entrenamiento (`train`) y el conjunto de prueba (`test`) para identificar qué características no están presentes en este último.
#
# Esto es importante para asegurarnos de que el modelo no utilice variables que no estarán disponibles en la predicción final.

# %%
# Verificar columnas ausentes en el conjunto de prueba
train_cols = set(train.columns)
test_cols = set(test.columns)

# Diferencia: columnas que están en train pero no en test
missing_in_test = train_cols - test_cols

# Mostrar resultados ordenados
missing_in_test = sorted(missing_in_test)
print(f'Columnas no disponibles en el conjunto de prueba ({len(missing_in_test)}):')
for col in missing_in_test:
    print(col)

# Tipos de datos de las columnas ausentes
train[missing_in_test].dtypes
# Out:
# Columnas no disponibles en el conjunto de prueba (34):
# final.output.concentrate_ag
# final.output.concentrate_au
# final.output.concentrate_pb
# final.output.concentrate_sol
# final.output.recovery
# final.output.tail_ag
# final.output.tail_au
# final.output.tail_pb
# final.output.tail_sol
# primary_cleaner.output.concentrate_ag
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.concentrate_pb
# primary_cleaner.output.concentrate_sol
# primary_cleaner.output.tail_ag
# primary_cleaner.output.tail_au
# primary_cleaner.output.tail_pb
# primary_cleaner.output.tail_sol
# rougher.calculation.au_pb_ratio
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.sulfate_to_au_concentrate
# rougher.output.concentrate_ag
# rougher.output.concentrate_au
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.recovery
# rougher.output.tail_ag
# rougher.output.tail_au
# ...

# %% [markdown]
# #### Resultado:
#
# Se identificaron X columnas que están presentes en el conjunto de entrenamiento pero ausentes en el de prueba. Estas columnas no deben utilizarse para el entrenamiento del modelo.
#
# Estas características incluyen objetivos como `rougher.output.recovery` y variables intermedias calculadas después del experimento.
#
# Los tipos de datos de estas columnas son principalmente `float64`.
#
# Como estas variables no están disponibles al momento de realizar predicciones, no deben incluirse como entradas en el modelo final.

# %% [markdown]
# ### 1.4. Preprocesamiento de datos
#
# En este paso realizaremos el preprocesamiento necesario para asegurar la calidad del conjunto de datos antes de construir modelos. Las tareas incluyen:
#
# - Verificamos que los archivos de entrenamiento, prueba y completos contienen la columna `date`.
# - Si la columna está presente, la convertimos a formato datetime y la usamos como índice temporal.
# - Luego, igualamos las columnas del conjunto de entrenamiento con las del conjunto de prueba, eliminando las columnas no presentes en este último.
# - Finalmente, eliminamos cualquier fila con valores faltantes.

# %%
# Verificamos las columnas presentes en los archivos
print("Columnas en train:", train.columns[:5])
print("Columnas en test:", test.columns[:5])
print("Columnas en full:", full.columns[:5])

# Verificamos si existe la columna 'date'
for name, df in zip(['train', 'test', 'full'], [train, test, full]):
    if 'date' not in df.columns:
        print(f"La columna 'date' no está en {name}")

# Recargamos los datos con seguridad (por si ya tenían 'date' como índice)
train_data = train.reset_index()
test_data = test.reset_index()
full_data = full.reset_index()

# Convertimos 'date' a datetime y la asignamos como índice
for df in [train_data, test_data, full_data]:
    df['date'] = pd.to_datetime(df['date'])
    df.set_index('date', inplace=True)

# Igualamos las columnas de entrenamiento con las de prueba (test no tiene columnas objetivo)
train_data = train_data[test_data.columns]  # solo las columnas que están en test

# Revisamos valores nulos antes de eliminar
print("Valores nulos en train:")
print(train_data.isnull().sum().value_counts())

print("\nValores nulos en test:")
print(test_data.isnull().sum().value_counts())

# Eliminamos filas con valores faltantes
train_data = train_data.dropna()
test_data = test_data.dropna()
# Out:
# Columnas en train: Index(['final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery'],
#       dtype='object')
# Columnas en test: Index(['primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air'],
#       dtype='object')
# Columnas en full: Index(['final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery'],
#       dtype='object')
# La columna 'date' no está en train
# La columna 'date' no está en test
# La columna 'date' no está en full
# Valores nulos en train:
# 53      5
# 85      4
# 58      3
# 27      3
# 51      2
# 113     2
# 40      2
# 46      1
# 1044    1
# 292     1
# 417     1
# 39      1
# 1904    1
# 623     1
# ...

# %% [markdown]
# #### Resultado del preprocesamiento (corregido):
#
# - La columna `date` fue correctamente localizada y usada como índice en todos los DataFrames.
# - Se igualaron las columnas del conjunto de entrenamiento a las del conjunto de prueba, excluyendo las no disponibles en este último.
# - Se eliminaron filas con valores nulos en ambos conjuntos.
# - Ambos DataFrames (`train_data` y `test_data`) están limpios, con columnas alineadas y listos para el análisis exploratorio.
#
# Pasamos ahora a la sección 2 del proyecto: Análisis de los datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Excelente comienzo! Has realizado una preparación de datos sólida y muy bien estructurada. La importación de bibliotecas, carga de archivos, verificación del cálculo de recuperación y análisis de las columnas disponibles están impecablemente ejecutados. La limpieza final asegura que los datos estén listos para el análisis. </div>

# %% [markdown]
# ## 2. Análisis de los datos
#
# ### 2.1 ¿Cómo cambia la concentración de metales (Au, Ag, Pb) según la etapa de purificación?
#
# Vamos a analizar cómo cambia la concentración de los metales oro (Au), plata (Ag) y plomo (Pb) a lo largo del proceso de purificación. Para ello, trazaremos gráficos de línea para cada metal en las diferentes etapas:
#
# - `rougher.output.concentrate_*`: primera etapa de flotación (rougher).
# - `primary_cleaner.output.concentrate_*`: primera etapa de limpieza (primary).
# - `final.output.concentrate_*`: salida final del concentrado.
#
# Este análisis ayudará a entender el comportamiento de los metales durante el proceso de refinamiento.

# %%
import matplotlib.pyplot as plt

# Lista de metales a analizar
metales = ['au', 'ag', 'pb']

# Crear los gráficos
for metal in metales:
    plt.figure(figsize=(12, 4))
    
    # Extraer series por etapa
    rougher = full_data[f'rougher.output.concentrate_{metal}']
    primary = full_data[f'primary_cleaner.output.concentrate_{metal}']
    final = full_data[f'final.output.concentrate_{metal}']
    
    # Graficar
    plt.plot(rougher.index, rougher, label='Rougher')
    plt.plot(primary.index, primary, label='Primary Cleaner')
    plt.plot(final.index, final, label='Final')
    plt.title(f'Concentración de {metal.upper()} por etapa de purificación')
    plt.xlabel('Fecha')
    plt.ylabel('Concentración')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 2.2 Comparar las distribuciones del tamaño de las partículas de alimentación en los conjuntos de entrenamiento y prueba
#
# El tamaño de las partículas en la alimentación puede afectar la eficiencia del proceso de extracción. Vamos a comparar la distribución de esta característica en los conjuntos `train` y `test`.
#
# Si las distribuciones son significativamente diferentes, esto puede influir negativamente en la evaluación del modelo, ya que estaría evaluando con datos que no representan bien la distribución usada en el entrenamiento.

# %%
import seaborn as sns

# Variable a comparar
columna_particulas = 'rougher.input.feed_size'

# Gráfico de distribución
plt.figure(figsize=(10, 5))
sns.kdeplot(train_data[columna_particulas], label='Train', fill=True)
sns.kdeplot(test_data[columna_particulas], label='Test', fill=True)
plt.title('Distribución del tamaño de partículas en la alimentación (feed_size)')
plt.xlabel('Tamaño de partícula')
plt.ylabel('Densidad')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3 Revisar concentraciones totales de sustancias y detectar valores anómalos
#
# Calculamos la suma de las concentraciones de los metales y sólidos en la materia prima.
# Luego, revisamos la estadística descriptiva para detectar valores fuera de rango (por ejemplo, suma 0 o mayor a 100%).
# Finalmente, visualizamos la distribución y eliminamos las filas anómalas para limpiar el conjunto de entrenamiento.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular la concentración total en la materia prima (entrada rougher)
train_data['input_total'] = (
    train_data['rougher.input.feed_ag'] +
    train_data['rougher.input.feed_pb'] +
    train_data['rougher.input.feed_au'] +
    train_data['rougher.input.feed_sol']
)

# Estadística descriptiva
print(train_data['input_total'].describe())

# Detectar valores anómalos (suma == 0 o suma > 100)
anomalies = train_data[(train_data['input_total'] == 0) | (train_data['input_total'] > 100)]
print(f"Filas anómalas encontradas: {len(anomalies)}")
print(anomalies.head())

# Visualización de la distribución
plt.figure(figsize=(10,5))
sns.histplot(train_data['input_total'], bins=50, kde=True)
plt.axvline(0, color='red', linestyle='--', label='Valor 0')
plt.axvline(100, color='orange', linestyle='--', label='Valor 100')
plt.title('Distribución de la concentración total en materia prima (input_total)')
plt.xlabel('Concentración total (%)')
plt.legend()
plt.show()

# Eliminar filas anómalas
train_cleaned = train_data[~((train_data['input_total'] == 0) | (train_data['input_total'] > 100))].copy()
print(f"Filas después de limpieza: {len(train_cleaned)}")
# Out:
# count    13522.000000
# mean        55.954111
# std          8.425658
# min          0.000000
# 25%         52.681865
# 50%         56.699759
# 75%         60.882912
# max         72.492216
# Name: input_total, dtype: float64
# Filas anómalas encontradas: 60
#                      primary_cleaner.input.sulfate  \
# date
# 2016-02-13 10:00:00                     134.891862
# 2016-03-02 21:00:00                      47.767327
# 2016-03-02 22:00:00                      44.556322
# 2016-04-24 14:59:59                      58.555288
# 2016-05-01 04:59:59                      11.158552
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-02-13 10:00:00                         13.976806
# 2016-03-02 21:00:00                          3.966140
# 2016-03-02 22:00:00                          4.095100
# 2016-04-24 14:59:59                          5.776989
# 2016-05-01 04:59:59                          1.050355
#
#                      primary_cleaner.input.feed_size  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Muy buen análisis exploratorio! Has aplicado correctamente gráficos comparativos para visualizar el comportamiento de los metales, evaluado diferencias en la distribución entre conjuntos y gestionado de forma precisa los valores anómalos. Esto da una base muy robusta para los próximos pasos del modelado. </div>

# %% [markdown]
# ## 3. Construye el modelo
#
# ## 3.1. Escribe una función para calcular el valor final de sMAPE.

# %%
# Reindexar df para que coincida con train_cleaned.index y luego asignar
df_reindexed = df.reindex(train_cleaned.index)

train_cleaned['rougher.output.recovery'] = df_reindexed['rougher.output.recovery']
train_cleaned['final.output.recovery'] = df_reindexed['final.output.recovery']

print(train_cleaned[['rougher.output.recovery', 'final.output.recovery']].head())
# Out:
#                      rougher.output.recovery  final.output.recovery
# date
# 2016-01-15 00:00:00                87.107763              70.541216
# 2016-01-15 01:00:00                86.843261              69.266198
# 2016-01-15 02:00:00                86.842308              68.116445
# 2016-01-15 03:00:00                87.226430              68.347543
# 2016-01-15 04:00:00                86.688794              66.927016

# %%
df_reindexed = df.reindex(train_cleaned.index)

train_cleaned['rougher.output.recovery'] = df_reindexed['rougher.output.recovery']
train_cleaned['final.output.recovery'] = df_reindexed['final.output.recovery']

print(train_cleaned[['rougher.output.recovery', 'final.output.recovery']].head())
# Out:
#                      rougher.output.recovery  final.output.recovery
# date
# 2016-01-15 00:00:00                87.107763              70.541216
# 2016-01-15 01:00:00                86.843261              69.266198
# 2016-01-15 02:00:00                86.842308              68.116445
# 2016-01-15 03:00:00                87.226430              68.347543
# 2016-01-15 04:00:00                86.688794              66.927016

# %%
# 1. Asegúrate de que las columnas se añadieron correctamente
print(train_cleaned[['rougher.output.recovery', 'final.output.recovery']].head())

# 2. Verifica si hay valores faltantes en las variables objetivo
print(train_cleaned[['rougher.output.recovery', 'final.output.recovery']].isnull().sum())

# 3. Si hay valores faltantes, decide qué hacer: eliminarlos o imputarlos
# Por ejemplo, para eliminar filas con valores nulos en las variables objetivo:
train_cleaned = train_cleaned.dropna(subset=['rougher.output.recovery', 'final.output.recovery'])

# 4. Confirma el tamaño final
print(train_cleaned.shape)

# 5. Guardar o seguir con el modelado
# Out:
#                      rougher.output.recovery  final.output.recovery
# date
# 2016-01-15 00:00:00                87.107763              70.541216
# 2016-01-15 01:00:00                86.843261              69.266198
# 2016-01-15 02:00:00                86.842308              68.116445
# 2016-01-15 03:00:00                87.226430              68.347543
# 2016-01-15 04:00:00                86.688794              66.927016
# rougher.output.recovery    695
# final.output.recovery      131
# dtype: int64
# (12679, 59)

# %%
train_cleaned = train_cleaned.dropna(subset=['rougher.output.recovery', 'final.output.recovery'])

# Verificar tamaño después de eliminar nulos
print(train_cleaned.shape)

# Confirmar que ya no hay nulos en esas columnas
print(train_cleaned[['rougher.output.recovery', 'final.output.recovery']].isnull().sum())
# Out:
# (12679, 59)
# rougher.output.recovery    0
# final.output.recovery      0
# dtype: int64

# %%
print(train_cleaned.isnull().sum().sum())  # Debe ser 0 para un dataset limpio

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Muy bien trabajado. Has gestionado con precisión la incorporación de las variables objetivo y la limpieza posterior. El control de valores nulos fue claro y ordenado, lo que garantiza que el conjunto esté completamente listo para el modelado. </div>

# %% [markdown]
# ## Comentario general del revisor

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades! Tu proyecto está **aprobado**. Has demostrado un excelente manejo de los datos, análisis exploratorio y preparación cuidadosa para el modelado. A continuación, destaco los puntos positivos y algunas áreas interesantes para seguir investigando:
#
# #### Puntos Positivos:
#
# * **Procesamiento de datos:** Excelente limpieza de valores nulos y verificación rigurosa de la estructura de los conjuntos.
# * **Visualización y análisis gráfico:** Gráficos claros y útiles para comprender el comportamiento de los metales y la consistencia entre conjuntos.
# * **Ingeniería de características:** Detectaste variables no disponibles para predicción y las excluiste correctamente, lo que fortalece la calidad del modelo.
# * **Comparación de distribuciones y detección de anomalías:** Identificaste diferencias clave y valores atípicos con criterio técnico y acciones apropiadas.
#
# #### Áreas para Seguir Investigando:
#
# * **Vectorización y optimización de código:** Explora métodos como `pipeline` de scikit-learn para automatizar limpieza y modelado.
# * **Técnicas avanzadas de feature engineering:** Prueba combinaciones de variables o agregaciones temporales si hay patrones por hora o día.
# * **Evaluación de modelos más complejos:** Considera ensambles como Random Forest o Gradient Boosting, además de regresiones básicas.
# * **Manejo de desbalanceo en los datos:** Aunque este proyecto no lo requería, conocer técnicas como SMOTE o undersampling te será útil.
#
# ¡Estás haciendo un gran trabajo!
#
# </div>
